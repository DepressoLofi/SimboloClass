# %%
import tensorflow as tf
import numpy as np

# %%
filename = '../datas/image/car.jpg'

# %% [markdown]
# First method to load an image

# %%
# first method to load image
from IPython.display import Image
img1 = Image(filename = '../datas/image/car.jpg', width=200, height=200)
img1

# %%
# second method to load image
from tensorflow.keras.preprocessing import image
img2 = image.load_img(filename, target_size =(224, 400))

# %%
import matplotlib.pyplot as plt
plt.imshow(img2)

# %%
# third method love this one
import cv2
img3 = cv2.imread(filename)
plt.imshow(img3)

# %%
img3 = cv2.resize(img3, (244, 244))
plt.imshow(img3)

# %%
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
#fourth method to load image
from PIL import Image

# %%
im = Image.open(filename)

# %%
im = im.resize((224, 224))
plt.imshow(im)

# %% [markdown]
# ## Deep learning model

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()
# deep learning pre trained
# Out:
# ...
# 17225924/17225924 [==============================] - 7s 0us/step

# %% [markdown]
# ## Preprocessing of the image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224, 224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img, axis=0)
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
print(predictions)
# Out:
# [[5.96283356e-10 2.16085178e-10 2.81562117e-11 1.74221713e-11
#   1.63803027e-10 1.76671733e-09 7.99731503e-10 2.71171388e-12
#   1.43011870e-11 1.65029726e-11 1.09462850e-09 2.22806418e-09
#   3.97369256e-11 2.48471881e-12 9.15591908e-12 3.86350882e-11
#   8.22072532e-12 5.31811357e-13 4.44162800e-13 5.65195842e-11
#   2.57537030e-11 1.50486867e-09 5.35772364e-11 7.13286208e-10
#   1.92472058e-12 6.48102821e-11 1.87538249e-11 2.18784886e-11
#   1.38751267e-11 3.54031422e-11 3.57693250e-11 2.03675166e-09
#   4.15430496e-10 1.04094031e-08 4.36055769e-09 5.04073415e-11
#   8.32163505e-10 2.85825912e-11 2.12454915e-10 3.61183089e-13
#   4.42556582e-11 2.34162841e-12 5.08012382e-11 7.99275091e-11
#   2.39305169e-12 1.61309559e-11 3.77115223e-12 4.45997156e-10
#   3.89273943e-12 3.02529540e-13 1.04618885e-12 1.84952290e-10
#   2.69723688e-10 1.72036788e-10 1.26732435e-11 1.72393183e-10
#   1.52135290e-10 2.37566217e-11 2.52344430e-11 7.42668593e-10
# ...

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results = imagenet_utils.decode_predictions(predictions)
# Out:
# ...
# 35363/35363 [==============================] - 0s 2us/step

# %%
print(results)
# Out:
# [[('n04285008', 'sports_car', 0.9899172), ('n04037443', 'racer', 0.0054752943), ('n03100240', 'convertible', 0.0033005876), ('n02974003', 'car_wheel', 0.00044281353), ('n03930630', 'pickup', 0.00043219337)]]

# %%
first_answer = results[0][0][1]

# %%
print(first_answer)
# Out:
# sports_car
